# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from fastai.vision import *
from fastai.metrics import error_rate

import shutil

loadpath = Path('/content/drive/My Drive/Colab Notebooks/caddy-accuracies/')

loadpath_ls = loadpath.ls()
for file in loadpath_ls:
    if 'accurac' in str(file):
        print(f'Copying saved csv: {file} to .')
        shutil.copy(file, '.')
# Out:
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/train_valid-df-model-A.csv to .
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/accuracies-df-model-B.csv to .
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/accuracies-df-model-A.csv to .
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/train_valid-df-model-F.csv to .
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/test-df-model-C.csv to .
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/test-df-model-B.csv to .
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/train_valid-df-model-C.csv to .
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/test-df-model-C.pkl to .
# Copying saved csv: /content/drive/My Drive/Colab Notebooks/caddy-accuracies/test-df-model-F.pkl to .
# ...

# %%
df_a = pd.read_csv('accuracies-df-model-A.csv', index_col=0)
df_b = pd.read_csv('accuracies-df-model-B.csv', index_col=0)
df_c = pd.read_csv('accuracies-df-model-C.csv', index_col=0)
df_f = pd.read_csv('accuracies-df-model-F.csv', index_col=0)

# %%
'''
df_a.columns = ['Scenario', 'Acc A']
df_b.columns = ['Scenario', 'Acc B']
df_c.columns = ['Scenario', 'Acc C']
df_f.columns = ['Scenario', 'Acc F']
'''
df_a.columns = ['Acc A']
df_b.columns = ['Acc B']
df_c.columns = ['Acc C']
df_f.columns = ['Acc F']

print(df_a)
print(df_b)
print(df_c)
print(df_f)
# Out:
#                 Acc A
# biograd-C    0.531025
# brodarski-A  0.522026
# brodarski-B  0.632184
# brodarski-C  0.571151
# brodarski-D  0.708333
# genova-A     0.341114
# overall      0.449128
#                 Acc B
# biograd-A    0.420428
# biograd-B    0.205641
# biograd-C    0.454294
# brodarski-A  0.244493
# brodarski-B  0.120690
# brodarski-C  0.214101
# brodarski-D  0.483025
# overall      0.360703
#                 Acc C
# biograd-A    0.495617
# biograd-B    0.605422
# biograd-C    0.512907
# brodarski-B  0.676829
# brodarski-D  0.529321
# genova-A     0.245358
# overall      0.433849
#                 Acc F
# biograd-A    0.994302
# biograd-B    0.995098
# biograd-C    0.972678
# brodarski-A  0.958333
# brodarski-B  0.863636
# brodarski-C  0.987421
# brodarski-D  1.000000
# genova-A     0.893871
# overall      0.951775

# %%
df_all = pd.concat([df_a, df_b, df_c, df_f], axis=1).fillna(0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
print(df_all)
# Out:
#                 Acc A     Acc B     Acc C     Acc F
# biograd-A    0.000000  0.420428  0.495617  0.994302
# biograd-B    0.000000  0.205641  0.605422  0.995098
# biograd-C    0.531025  0.454294  0.512907  0.972678
# brodarski-A  0.522026  0.244493  0.000000  0.958333
# brodarski-B  0.632184  0.120690  0.676829  0.863636
# brodarski-C  0.571151  0.214101  0.000000  0.987421
# brodarski-D  0.708333  0.483025  0.529321  1.000000
# genova-A     0.341114  0.000000  0.245358  0.893871
# overall      0.449128  0.360703  0.433849  0.951775

# %%
df_all.to_latex(index=True, float_format="{:0.3f}".format)
# Out:
# '\\begin{tabular}{lrrrr}\n\\toprule\n{} &  Acc A &  Acc B &  Acc C &  Acc F \\\\\n\\midrule\nbiograd-A   &  0.000 &  0.420 &  0.496 &  0.994 \\\\\nbiograd-B   &  0.000 &  0.206 &  0.605 &  0.995 \\\\\nbiograd-C   &  0.531 &  0.454 &  0.513 &  0.973 \\\\\nbrodarski-A &  0.522 &  0.244 &  0.000 &  0.958 \\\\\nbrodarski-B &  0.632 &  0.121 &  0.677 &  0.864 \\\\\nbrodarski-C &  0.571 &  0.214 &  0.000 &  0.987 \\\\\nbrodarski-D &  0.708 &  0.483 &  0.529 &  1.000 \\\\\ngenova-A    &  0.341 &  0.000 &  0.245 &  0.894 \\\\\noverall     &  0.449 &  0.361 &  0.434 &  0.952 \\\\\n\\bottomrule\n\\end{tabular}\n'
